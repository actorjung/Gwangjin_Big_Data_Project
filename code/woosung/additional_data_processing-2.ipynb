# %%
import pandas as pd
import os

# %%
#경로설정 읽어오는 경로, 저장하는 경로
Path = os.path.join('Users','woosung','Gwangjin_project','additional_data')
path_result = os.path.join('Users','woosung','Gwangjin_project','additional_data','processing_result')

# %% [markdown]
# # 1. 서울시 광진구 점포 인허가 정보

# %% [markdown]
# ## 1-1. 대규모 점포

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_1 = pd.read_csv(f"/{Path}/점포/서울시 광진구 대규모점포 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_1 = df1_1[["점포구분명","상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]

# %%
df1_1 = df1_1.drop(df1_1[df1_1['상세영업상태명'] == '폐업처리'].index)

# %%
df1_1["점포구분명"] = df1_1["점포구분명"].fillna("대규모점포")

# %%
df1_1
# Out:
#     점포구분명 상세영업상태명                 사업장명        좌표정보(X)        좌표정보(Y)
# 0   대규모점포    정상영업                노룬산시장  205663.081069  448250.363359
# 1   대규모점포    정상영업                 조양시장  205886.288968  448517.338628
# 2   대규모점포    정상영업               중곡제일시장  207114.498872  451296.049444
# 5   대규모점포    정상영업               신성종합시장  207747.893953  450639.201015
# 7   대규모점포    정상영업               자양종합시장  206686.364451  447752.463190
# 8   대규모점포    정상영업                한아름시장  206107.775164  449029.342178
# 9   대규모점포    정상영업                 광성시장  207098.994773  451260.445741
# 10  대규모점포    정상영업             동서울터미널상가  208201.993321  447967.299542
# 11  대규모점포    정상영업               현대종합상가  208644.819210  448711.725750
# 12  대규모점포    정상영업             구의현대종합상가  208403.746066  448490.239180
# 13  대규모점포    정상영업             프라임프라자상가  208558.286632  448353.905156
# 14  대규모점포    정상영업             테크노-마트21  208394.416382  448165.280000
# 15  대규모점포    정상영업      롯데쇼핑(주)롯데마트 강변점  208394.416382  448165.280000
# ...

# %%
#전처리 데이터 저장
df1_1.to_csv(f"/{path_result}/서울시 광진구 대규모점포 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-2. 관광공영장업

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_2 = pd.read_csv(f"/{Path}/점포/서울시 광진구 관광공연장업 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_2 = df1_2[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]

# %%
df1_2 = df1_2.drop(df1_2[df1_2['상세영업상태명'] == '폐업'].index)

# %%
df1_2.insert(0, '점포구분명', "관광공연장업")

# %%
df1_2
# Out:
#     점포구분명 상세영업상태명    사업장명        좌표정보(X)        좌표정보(Y)
# 1  관광공연장업     영업중  동서울아트홀  208051.884671  447994.805558

# %%
#전처리 데이터 저장
df1_2.to_csv(f"/{path_result}/서울시 광진구 관광공연장업 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-3. 관광숙박업

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_3 = pd.read_csv(f"/{Path}/점포/서울시 광진구 관광숙박업 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_3 = df1_3[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]

# %%
df1_3 = df1_3.drop(df1_3[df1_3['상세영업상태명'] == '폐업'].index)

# %%
df1_3.insert(0, '점포구분명', "관광숙박업")

# %%
df1_3
# Out:
#     점포구분명 상세영업상태명             사업장명        좌표정보(X)        좌표정보(Y)
# 0   관광숙박업     영업중         동서울 관광호텔  208051.884671  447994.805558
# 1   관광숙박업     영업중  SK 네트웍스 (주) 워커힐  209775.267832  450327.577093
# 5   관광숙박업     영업중    더 클래식 500 펜타즈  206217.434726  448506.218744
# 6   관광숙박업     영업중        호텔 컬리넌 건대  206032.404204  449812.167768
# 7   관광숙박업     영업중       호텔더디자이너스건대  206698.893815  450714.384111
# 8   관광숙박업     영업중          호텔부티크나인  207010.871584  450476.132985
# 9   관광숙박업     영업중         호텔컬리넌건대2  206049.041722  449837.413487
# 11  관광숙박업     영업중      에이치 에비뉴 건대점  205814.775584  449312.470283
# 12  관광숙박업     영업중   호텔더디자이너스프리미어건대  205879.365670  449454.638560
# 13  관광숙박업     영업중             휴호스텔  207451.978559  448383.349036
# 14  관광숙박업     영업중           호텔케이월드  205540.082599  448702.306850
# 15  관광숙박업     영업중             나무호텔  209407.745384  449459.252995

# %%
#전처리 데이터 저장
df1_3.to_csv(f"/{path_result}/서울시 광진구 관광숙박업 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-4. 병원

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_4 = pd.read_csv(f"/{Path}/점포/서울시 광진구 병원 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_4 = df1_4[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]

# %%
df1_4 = df1_4.drop(df1_4[df1_4['상세영업상태명'] == '폐업'].index)

# %%
df1_4.insert(0, '점포구분명', "병원")

# %%
df1_4
# Out:
#    점포구분명 상세영업상태명         사업장명        좌표정보(X)        좌표정보(Y)
# 0     병원     영업중     국립정신건강센터  207510.076792  451417.864439
# 1     병원     영업중      건국대학교병원  206303.032229  448689.878162
# 2     병원     영업중         혜민병원  207307.270592  448107.552521
# 5     병원     영업중      광진예치과병원  206972.721585  450495.893227
# 7     병원     영업중        제니스병원  207569.609747  449364.569116
# 9     병원     영업중  에스(S)리더치과병원  206163.281974  448682.578828
# 11    병원     영업중        바른본병원  206746.708330  450141.931842
# 12    병원     영업중     연세무척나은병원  207070.392316  450446.773797
# 13    병원     영업중    동부참사랑요양병원  205799.162717  449285.820249
# 14    병원     영업중      서울프라임병원  205558.677067  448728.056778
# 15    병원     영업중      편안한요양병원  207574.350933  447709.275316
# 16    병원     영업중       오석한방병원  207342.766107  448444.754635
# 17    병원     영업중     경희생생한방병원  205507.103015  448633.824456

# %%
#전처리 데이터 저장
df1_4.to_csv(f"/{path_result}/서울시 광진구 병원 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-5. 숙박업

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_5 = pd.read_csv(f"/{Path}/점포/서울시 광진구 숙박업 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_5 = df1_5[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]
df1_5 = df1_5.drop(df1_5[df1_5['상세영업상태명'] == '폐업'].index)
df1_5.insert(0, '점포구분명', "숙박업")

# %%
df1_5
# Out:
#     점포구분명 상세영업상태명              사업장명        좌표정보(X)        좌표정보(Y)
# 0     숙박업      영업               워커힐  209775.267832  450327.577093
# 8     숙박업      영업              큐(Q)  205850.752898  449421.557205
# 9     숙박업      영업             그랜드모텔  205776.113128  449246.304001
# 13    숙박업      영업              황금모텔  207616.439261  449241.028370
# 14    숙박업      영업              신한모텔  206217.242617  449008.155442
# ..    ...     ...               ...            ...            ...
# 173   숙박업      영업     에이치에비뉴 호텔 건대점  205814.775584  449312.470283
# 174   숙박업      영업  호텔더디자이너스 프리미어 건대  205879.365670  449454.638560
# 175   숙박업      영업            호텔케이월드  205540.082599  448702.306850
# 176   숙박업      영업        호텔더디자이너스건대  206698.893815  450714.384111
# 177   숙박업      영업              나무호텔  209407.745384  449459.252995
#
# [68 rows x 5 columns]

# %%
#전처리 데이터 저장
df1_5.to_csv(f"/{path_result}/서울시 광진구 숙박업 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-6. 영화상영관

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_6 = pd.read_csv(f"/{Path}/점포/서울시 광진구 영화상영관 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_6 = df1_6[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]
df1_6 = df1_6.drop(df1_6[df1_6['상세영업상태명'] == '폐업'].index)
df1_6.insert(0, '점포구분명', "영화상영관")

# %%
df1_6
# Out:
#     점포구분명 상세영업상태명                    사업장명        좌표정보(X)        좌표정보(Y)
# 0   영화상영관     영업중         CGV강변11 STAR 2관  208394.416382  448165.280000
# 1   영화상영관     영업중         CGV강변11 STAR 3관  208394.416382  448165.280000
# 2   영화상영관     영업중          CGV강변11 4DX 1관  208394.416382  448165.280000
# 3   영화상영관     영업중  CGV강변11 제4관[CGV 아트하우스]  208394.416382  448165.280000
# 4   영화상영관     영업중             CGV강변11 제5관  208394.416382  448165.280000
# 5   영화상영관     영업중             CGV강변11 제6관  208394.416382  448165.280000
# 6   영화상영관     영업중             CGV강변11 제7관  208394.416382  448165.280000
# 7   영화상영관     영업중             CGV강변11 제8관  208394.416382  448165.280000
# 8   영화상영관     영업중             CGV강변11 제9관  208394.416382  448165.280000
# 9   영화상영관     영업중            CGV강변11 제10관  208394.416382  448165.280000
# 10  영화상영관     영업중   CGV강변 11 CINE & FORET  208394.416382  448165.280000
# 11  영화상영관     영업중       롯데시네마 건대입구관 (제4관)  206349.675048  448396.939704
# ...

# %%
#전처리 데이터 저장
df1_6.to_csv(f"/{path_result}/서울시 광진구 영화상영관 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-7. 일반유원시설업

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_7 = pd.read_csv(f"/{Path}/점포/서울시 광진구 일반유원시설업 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_7 = df1_7[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]
df1_7 = df1_7.drop(df1_7[df1_7['상세영업상태명'] == '폐업'].index)
df1_7.insert(0, '점포구분명', "일반유원시설업")

# %%
df1_7["좌표정보(X)"] = df1_7["좌표정보(X)"].fillna(0)
df1_7["좌표정보(Y)"] = df1_7["좌표정보(Y)"].fillna(0)

# %%
df1_7
# Out:
#      점포구분명 상세영업상태명           사업장명        좌표정보(X)        좌표정보(Y)
# 0  일반유원시설업      휴업       워커힐 리버파크       0.000000       0.000000
# 5  일반유원시설업      휴업            노리터  207039.842488  449315.360320
# 7  일반유원시설업    허가취소  어린이대공원놀이동산(주)  207138.865763  449705.690587

# %%
#전처리 데이터 저장
df1_7.to_csv(f"/{path_result}/서울시 광진구 일반유원시설업 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-8. 일반음식점

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_8 = pd.read_csv(f"/{Path}/점포/서울시 광진구 일반음식점 인허가 정보.csv",encoding = 'cp949')
# Out:
# /var/folders/0k/y54m5g4d2lb53hr83x8nyz400000gn/T/ipykernel_2347/3657425272.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1_8 = pd.read_csv(f"/{Path}/점포/서울시 광진구 일반음식점 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_8 = df1_8[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]
df1_8 = df1_8.drop(df1_8[df1_8['상세영업상태명'] == '폐업'].index)
df1_8.insert(0, '점포구분명', "일반음식점")

# %%
#nan값 행 확인
df1_8[df1_8["좌표정보(X)"].isnull()]
# Out:
#        점포구분명 상세영업상태명        사업장명  좌표정보(X)  좌표정보(Y)
# 1058   일반음식점      영업        명랑식당      NaN      NaN
# 5370   일반음식점      영업       다이스호프      NaN      NaN
# 6215   일반음식점      영업        둘리치킨      NaN      NaN
# 6731   일반음식점      영업       허씨네통닭      NaN      NaN
# 8472   일반음식점      영업    아!너무좋아닭발      NaN      NaN
# 15201  일반음식점      영업        익선포차      NaN      NaN
# 15203  일반음식점      영업  벤앤제리스아이스크림      NaN      NaN
# 15860  일반음식점      영업        구이도씨      NaN      NaN
# 15960  일반음식점      영업         126      NaN      NaN
# 16135  일반음식점      영업      배떡 광장점      NaN      NaN
# 16136  일반음식점      영업    오고(OHGO)      NaN      NaN
# 16251  일반음식점      영업      블루파인애플      NaN      NaN

# %%
df1_8
# Out:
#        점포구분명 상세영업상태명                  사업장명        좌표정보(X)        좌표정보(Y)
# 6      일반음식점      영업                  서북면옥  207471.153472  449242.931984
# 12     일반음식점      영업                   가람성  206685.852737  449228.796632
# 16     일반음식점      영업                   샤브삘  207380.463781  448387.748171
# 17     일반음식점      영업                 세꼬시마을  206715.264662  450582.951056
# 38     일반음식점      영업                  서울회관  206953.081817  447676.267046
# ...      ...     ...                   ...            ...            ...
# 16625  일반음식점      영업               미스고기건대점  206135.609363  449591.555580
# 16626  일반음식점      영업                   참치네  207103.703162  451364.843844
# 16627  일반음식점      영업         퍼틴쌀국수체인점(건대점)  206019.917491  448895.074137
# 16628  일반음식점      영업   에스에스컴퍼니(SS company)  207587.346588  450767.411710
# 16629  일반음식점      영업  에스에이치컴퍼니(SH company)  207587.346588  450767.411710
#
# [4295 rows x 5 columns]

# %%
#전처리 데이터 저장
df1_8.to_csv(f"/{path_result}/서울시 광진구 일반음식점 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-9. 종합체육시설업

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_9 = pd.read_csv(f"/{Path}/점포/서울시 광진구 종합체육시설업 인허가 정보.csv",encoding = 'cp949')

# %%
df1_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   개방자치단체코드  6 non-null      int64
#  1   관리번호      6 non-null      object
#  2   인허가일자     6 non-null      int64
#  3   인허가취소일자   0 non-null      float64
#  4   영업상태코드    6 non-null      int64
#  5   영업상태명     6 non-null      object
#  6   상세영업상태코드  6 non-null      int64
#  7   상세영업상태명   6 non-null      object
#  8   폐업일자      4 non-null      float64
#  9   휴업시작일자    0 non-null      float64
#  10  휴업종료일자    0 non-null      float64
#  11  재개업일자     0 non-null      float64
#  12  전화번호      6 non-null      object
#  13  소재지면적     0 non-null      float64
#  14  소재지우편번호   6 non-null      int64
#  15  지번주소      6 non-null      object
#  16  도로명주소     3 non-null      object
#  17  도로명우편번호   2 non-null      float64
#  18  사업장명      6 non-null      object
#  19  최종수정일자    6 non-null      object
# ...

# %% [markdown]
# ### 전처리

# %%
df1_9 = df1_9[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]
df1_9 = df1_9.drop(df1_9[df1_9['상세영업상태명'] == '폐업'].index)
df1_9.insert(0, '점포구분명', "종합체육시설업")

# %%
df1_9
# Out:
#      점포구분명 상세영업상태명           사업장명        좌표정보(X)        좌표정보(Y)
# 3  종합체육시설업     영업중  SK네트웍스(주) 워커힐  209775.267832  450327.577093
# 5  종합체육시설업     영업중         루(ROO)  209775.267832  450327.577093

# %%
#전처리 데이터 저장
df1_9.to_csv(f"/{path_result}/서울시 광진구 종합체육시설업 인허가 정보.csv", index = False)

# %% [markdown]
# ## 1-10. 학교

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_10 = pd.read_csv(f"/{Path}/점포/서울시 광진구 학교 기본정보.csv",encoding = 'cp949')

# %%
df1_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   학교종류명        120 non-null    object
#  1   설립구분         120 non-null    object
#  2   표준학교코드       120 non-null    int64
#  3   학교명          120 non-null    object
#  4   영문학교명        120 non-null    object
#  5   관할조직명        120 non-null    object
#  6   도로명우편번호      120 non-null    int64
#  7   도로명주소        120 non-null    object
#  8   도로명상세주소      120 non-null    object
#  9   전화번호         120 non-null    object
#  10  홈페이지주소       120 non-null    object
#  11  팩스번호         120 non-null    object
#  12  남녀공학구분명      120 non-null    object
#  13  고등학교구분명      83 non-null     object
#  14  산업체특별학급존재여부  120 non-null    object
#  15  고등학교일반실업구분명  120 non-null    object
#  16  특수목적고등학교계열명  23 non-null     object
#  17  입시전후기구분명     120 non-null    object
# ...

# %% [markdown]
# ### 전처리

# %%
df1_10 = df1_10[["학교명","도로명주소"]]
df1_10.insert(0, '점포구분명', "학교")

# %%
df1_10
# Out:
#     점포구분명      학교명                    도로명주소
# 0      학교  선화예술중학교       서울특별시 광진구 천호대로 664
# 1      학교    자양중학교      서울특별시 광진구 뚝섬로41길 33
# 2      학교    용곡중학교     서울특별시 광진구 용마산로22길 76
# 3      학교    양진중학교        서울특별시 광진구 워커힐로 32
# 4      학교    신양중학교       서울특별시 광진구 자양강변길 73
# ..    ...      ...                      ...
# 115    학교   광양고등학교      서울특별시 광진구 자양로3가길 31
# 116    학교   광남고등학교  서울특별시 광진구 아차산로70길 17-16
# 117    학교   광남고등학교  서울특별시 광진구 아차산로70길 17-16
# 118    학교   광남고등학교  서울특별시 광진구 아차산로70길 17-16
# 119    학교   광남고등학교  서울특별시 광진구 아차산로70길 17-16
#
# [120 rows x 3 columns]

# %%
#전처리 데이터 저장
df1_10.to_csv(f"/{path_result}/서울시 광진구 학교 기본정보.csv", index = False)

# %% [markdown]
# ## 1-11. 휴게음식점

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df1_11 = pd.read_csv(f"/{Path}/점포/서울시 광진구 휴게음식점 인허가 정보.csv",encoding = 'cp949')

# %% [markdown]
# ### 전처리

# %%
df1_11 = df1_11[["상세영업상태명","사업장명","좌표정보(X)","좌표정보(Y)"]]
df1_11 = df1_11.drop(df1_11[df1_11['상세영업상태명'] == '폐업'].index)
df1_11.insert(0, '점포구분명', "휴게음식점")

# %%
#nan값 행 확인
df1_11[df1_11["좌표정보(X)"].isnull()]
# Out:
#       점포구분명 상세영업상태명           사업장명  좌표정보(X)  좌표정보(Y)
# 1266  휴게음식점      영업  세븐일레븐(S아차산역점)      NaN      NaN
# 1834  휴게음식점      영업  GS25 S뚝섬유원지역점      NaN      NaN
# 2433  휴게음식점      영업        공차아차산역점      NaN      NaN
# 3613  휴게음식점      영업            온이유      NaN      NaN
# 3799  휴게음식점      영업           크로플각      NaN      NaN
# 3927  휴게음식점      영업       굿뉴스 그로서리      NaN      NaN
# 3945  휴게음식점      영업      에그토스트 구의점      NaN      NaN
# 3959  휴게음식점      영업          카페프렌즈      NaN      NaN
# 3977  휴게음식점      영업   컴포즈커피 세종대학교점      NaN      NaN

# %%
df1_11
# Out:
#       점포구분명 상세영업상태명           사업장명        좌표정보(X)        좌표정보(Y)
# 128   휴게음식점      영업           동부다방  207622.582506  448374.803680
# 294   휴게음식점      영업             꽃빙  208201.993321  447967.299542
# 302   휴게음식점      영업           킹스커피  206170.436231  448717.665412
# 781   휴게음식점      영업            토마토  208394.416382  448165.280000
# 782   휴게음식점      영업  할리스커피(테크노마트점)  208394.416382  448165.280000
# ...     ...     ...            ...            ...            ...
# 4173  휴게음식점      영업  메가엠지씨커피 중곡대원점  207626.759613  451292.042140
# 4174  휴게음식점      영업            라면킹  207351.817447  450851.805639
# 4175  휴게음식점      영업       씨유 광진광남점  208873.295567  448861.369466
# 4176  휴게음식점      영업    지에스25 구의한양점  208051.953679  447854.805964
# 4177  휴게음식점      영업          크로플이지  205546.767204  448164.792836
#
# [1365 rows x 5 columns]

# %%
#전처리 데이터 저장
df1_11.to_csv(f"/{path_result}/서울시 광진구 휴게음식점 인허가 정보.csv", index = False)

# %% [markdown]
# ***

# %% [markdown]
# ## 1-12. 점포별 합치기

# %% [markdown]
# ### 학교는 빼고 합침

# %%
df1_12 = pd.concat([df1_1, df1_2,df1_3,df1_4,df1_5,df1_6,df1_7,df1_8,df1_9,df1_11])

# %%
df1_12
# Out:
#       점포구분명 상세영업상태명           사업장명        좌표정보(X)        좌표정보(Y)
# 0     대규모점포    정상영업          노룬산시장  205663.081069  448250.363359
# 1     대규모점포    정상영업           조양시장  205886.288968  448517.338628
# 2     대규모점포    정상영업         중곡제일시장  207114.498872  451296.049444
# 5     대규모점포    정상영업         신성종합시장  207747.893953  450639.201015
# 7     대규모점포    정상영업         자양종합시장  206686.364451  447752.463190
# ...     ...     ...            ...            ...            ...
# 4173  휴게음식점      영업  메가엠지씨커피 중곡대원점  207626.759613  451292.042140
# 4174  휴게음식점      영업            라면킹  207351.817447  450851.805639
# 4175  휴게음식점      영업       씨유 광진광남점  208873.295567  448861.369466
# 4176  휴게음식점      영업    지에스25 구의한양점  208051.953679  447854.805964
# 4177  휴게음식점      영업          크로플이지  205546.767204  448164.792836
#
# [5823 rows x 5 columns]

# %%
#전처리 데이터 저장
df1_12.to_csv(f"/{path_result}/서울시 광진구 점포별(학교제외) 인허가 정보.csv", index = False)

# %% [markdown]
# ### 위도,경도 NAN값 제거

# %%
df= pd.read_csv(f"/{path_result}/서울시 광진구 점포별(학교제외) 인허가 정보.csv",encoding = 'UTF8')

# %%
df[df["좌표정보(X)"].isnull()]
# Out:
#         점포구분명 상세영업상태명           사업장명  좌표정보(X)  좌표정보(Y)
# 24      대규모점포    정상영업   구의 자이르네 판매시설      NaN      NaN
# 158   일반유원시설업      휴업       워커힐 리버파크      NaN      NaN
# 268     일반음식점      영업           명랑식당      NaN      NaN
# 669     일반음식점      영업          다이스호프      NaN      NaN
# 761     일반음식점      영업           둘리치킨      NaN      NaN
# 821     일반음식점      영업          허씨네통닭      NaN      NaN
# 1090    일반음식점      영업       아!너무좋아닭발      NaN      NaN
# 3381    일반음식점      영업           익선포차      NaN      NaN
# 3383    일반음식점      영업     벤앤제리스아이스크림      NaN      NaN
# 3803    일반음식점      영업           구이도씨      NaN      NaN
# 3878    일반음식점      영업            126      NaN      NaN
# 4011    일반음식점      영업         배떡 광장점      NaN      NaN
# 4012    일반음식점      영업       오고(OHGO)      NaN      NaN
# 4096    일반음식점      영업         블루파인애플      NaN      NaN
# 4538    휴게음식점      영업  세븐일레븐(S아차산역점)      NaN      NaN
# 4636    휴게음식점      영업  GS25 S뚝섬유원지역점      NaN      NaN
# ...

# %% [markdown]
# ***

# %% [markdown]
# # 2. 서울시 행정동별 생활인구

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df2 = pd.read_csv(f"/{Path}/행정동 단위 서울 생활인구(내국인).csv",encoding = 'cp949')

# %%
#광진구 행정동 딕셔너리
Gwang_bubjungdong_dict = {11215710 : "화양동",
              11215730 : "군자동",
11215740 : "중곡1동",
11215750 : "중곡2동",
11215760 : "중곡3동",
11215770 : "중곡4동",
11215780 : "능동",
11215850 : "구의1동",
11215860 : "구의2동",
11215870 : "구의3동",
11215810 : "광장동",
11215820 : "자양1동",
11215830 : "자양2동",
11215840 : "자양3동"
}

# %%
#행정동id별 승객수
df2_1 = df2.loc[df2['행정동코드'].isin([11215710,
11215730,
11215740,
11215750,
11215760,
11215770,
11215780,
11215850,
11215860,
11215870,
11215810,
11215820,
11215830,
11215840,
])]

# %%
#날짜별 승객수
df2_1 = df2_1.loc[df2_1['기준일ID'].isin([20230301,
         20230302,
         20230303,
         20230304,
         20230305,
         20230306,
         20230307,
         20230308,
         20230309,
         20230310,
         20230311,
         20230312,
         20230313,
         20230314,
         20230315,
         20230316,
         20230317,
         20230318,
         20230319,
         20230320,
         20230321,
         20230322,
         20230323,
         20230324,
         20230325,
         20230326,
         20230327,
         20230328,
         20230329,
         20230330])]

# %%
df2_1 = df2_1[["기준일ID","행정동코드","총생활인구수"]]

# %%
df2_1['행정동코드'] = df2_1['행정동코드'].map(Gwang_bubjungdong_dict)

# %%
df2_2 = df2_1.groupby('행정동코드').agg({'총생활인구수': 'mean'}).reset_index()

# %%
df2_2
# Out:
#    행정동코드        총생활인구수
# 0    광장동  35631.557045
# 1   구의1동  24941.159033
# 2   구의2동  21536.960275
# 3   구의3동  31418.233834
# 4    군자동  21267.531150
# 5     능동  15946.235261
# 6   자양1동  24613.383368
# 7   자양2동  21246.671009
# 8   자양3동  23291.388717
# 9   중곡1동  15321.501437
# 10  중곡2동  18097.396532
# 11  중곡3동  15333.167407
# 12  중곡4동  25153.672699
# 13   화양동  41651.908179

# %%
#전처리 데이터 저장
df2_2.to_csv(f"/{path_result}/행정동 단위 서울 평균 생활인구(내국인).csv", index = False)

# %% [markdown]
# # 3. 서울시 행정동별 대중교통 총 승차 승객수 정보

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df5 = pd.read_csv(f"/{Path}/서울시 행정동별 대중교통 총 승차 승객수 정보.csv",encoding = 'cp949')

# %%
#맥북은 인코딩 방식을 utf-8사용하기 때문에 윈도우 방식인 cp949로 인코딩을 해준다.
df6 = pd.read_csv(f"/{Path}/.csv",encoding = 'cp949')

# %% [markdown]
# https://data.seoul.go.kr/dataList/OA-21223/S/1/datasetView.do
#
# 대중교통이 버스인지 지하철인지 모르겠음 통합인가?
#
# 기준날짜 주말이랑 평일 코로나 풀린 이후로 하겠음

# %%
#광진구 행정동 딕셔너리
Gwang_dict = {1105053 : "화양동",
              1105054 : "군자동",
1105055 : "중곡1동",
1105056 : "중곡2동",
1105057 : "중곡3동",
1105058 : "중곡4동",
1105059 : "능동",
1105060 : "구의1동",
1105061 : "구의2동",
1105062 : "구의3동",
1105063 : "광장동",
1105064 : "자양1동",
1105065 : "자양2동",
1105066 : "자양3동"
}

# %% [markdown]
# ## 5-1. 2월 28일부터 3월 29일 1달간 대중교통 이용수 평균 구하기

# %%
#날짜별
df5_1 = df5.loc[df5['기준_날짜'].isin([20230228,
                                     20230301,
                                     20230302,
                                     20230303,
                                     20230304,
                                     20230305,
                                     20230306,
                                     20230307,
                                     20230308,
                                     20230309,
                                     20230310,
                                     20230311,
                                     20230312,
                                     20230313,
                                     20230314,
                                     20230315,
                                     20230316,
                                     20230317,
                                     20230318,
                                     20230319,
                                     20230320,
                                     20230321,
                                     20230322,
                                     20230323,
                                     20230324,
                                     20230325,
                                     20230326,
                                     20230327,
                                     20230328,
                                     20230329])]

# %%
#행정동id별 승객수
df5_1 = df5_1.loc[df5_1['행정동_ID'].isin([1105053,
                                     1105054,
                                     1105055,
                                     1105056,
                                     1105057,
                                     1105058,
                                     1105059,
                                     1105060,
                                     1105061,
                                     1105062,
                                     1105063,
                                     1105064,
                                     1105065,
                                     1105066])]

# %%
df5_1 = df5_1[["기준_날짜","행정동_ID","승객_수"]]

# %%
df5_1['행정동_ID'] = df5_1['행정동_ID'].map(Gwang_dict)

# %%
df5_2 = df5_1.groupby('행정동_ID').agg({'승객_수': 'mean'}).reset_index()

# %%
df5_2
# Out:
#    행정동_ID          승객_수
# 0     광장동  19139.800000
# 1    구의1동  31108.533333
# 2    구의2동  23029.066667
# 3    구의3동  37873.733333
# 4     군자동   8888.033333
# 5      능동  51069.466667
# 6    자양1동   6079.333333
# 7    자양2동   6565.800000
# 8    자양3동   6249.266667
# 9    중곡1동   4287.700000
# 10   중곡2동   5742.366667
# 11   중곡3동  15739.766667
# 12   중곡4동   3513.100000
# 13    화양동  62887.100000

# %%
#전처리 데이터 저장
df5_2.to_csv(f"/{path_result}/서울시 행정동별 대중교통 평균 승차 승객수 정보.csv", index = False)
