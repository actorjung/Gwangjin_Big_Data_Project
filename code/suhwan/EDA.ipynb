# %%
import pandas as pd

# %%
path='C:/Users/shjo/Desktop/gwangjin_data/전처리/Gwangjin_project/data'

# %% [markdown]
# # 1. 공영 주차장 + 불법주정차 + 교통단속

# %% [markdown]
# # 1.1 공영 주차장

# %%
df1=pd.read_csv(f"{path}/2014년도 광진구시설관리공단 공영주차장현황..csv",encoding='cp949')

# %%
df1
# Out:
#     관리번호       주차장명 주차장형태  운영방식                 주차장위치  주차면수 유,무료   급지  \
# 0      1   동서울호텔길 A    노상    직영  광진구 구의강변로 38(구의동) 일대    45   유료  2급지
# 1      2   동서울호텔길 A    노상    직영  광진구 구의강변로 38(구의동) 일대    47   유료  2급지
# 2      3    송림식당길 A    노상    직영       광진구 자양3동 712 일대    85   유료  2급지
# 3      4    송림식당길 B    노상    직영      광진구 자양동 581-2 일대    17   유료  2급지
# 4      5       광진광장    노외    직영     광진구 광나루로 389(군자동)    36   유료  2급지
# 5      6       자양4동    노외    직영          광진구 자양4동 5-5    86   유료  4급지
# 6      7       구의1동    노외    직영    광진구 자양로18길 78(구의동)   172   유료  2급지
# 7      8       구의3동    노외    직영    광진구 광나루52길 83(구의동)   160   유료  4급지
# 8      9         능동    노외    직영  광진구 천호대로 112길 56(능동)    77   유료  4급지
# 9     10  중곡3동 마을공원    노외    직영  광진구 용마산로 33길 25(중곡동)   163   유료  5급지
# 10    11    자양동 유수지    노외    직영         광진구 뚝섬로52길 74   289   유료  4급지
# 11    12        화양동    노외  민간위탁         광진구 군자로 6길 56    44   유료  4급지
# ...

# %%
df1=df1[['주차장명','주차면수',' 시간당주차요금 ']]

# %%
df1[' 시간당주차요금 ']=df1[' 시간당주차요금 ']//12
# Out:
# C:\Users\shjo\AppData\Local\Temp\ipykernel_31292\2401491392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[' 시간당주차요금 ']=df1[' 시간당주차요금 ']//12

# %%
lat_dic={'경도':[127.091861,127.091861,127.076033,127.075217,127.073625,127.068162,127.087849,127.091335,127.080217,127.084637,127.077510,127.072242,127.083247,27.083247,127.088348]}
lon_dic={'위도':[37.5341503,37.5341503,37.5344317,37.5328825,37.5477409,37.5386621,37.5382618,37.5390972,37.5540256,37.5699430,37.5293671,37.5455613,37.5615288,37.5615288,37.5580383]}
dong_dic={'동명':['구의3동','구의3동','자양3동','자양3동','군자동','자양4동','구의1동','구의3동','능동','중곡3동','자양2동','화양동','중곡2동','중곡2동','중곡4동']}
lat=pd.DataFrame(lat_dic)
lon=pd.DataFrame(lon_dic)
dong=pd.DataFrame(dong_dic)
df1['경도']=lat
df1['위도']=lon
df1['동명']=dong
# Out:
# C:\Users\shjo\AppData\Local\Temp\ipykernel_31292\3593587878.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['경도']=lat
# C:\Users\shjo\AppData\Local\Temp\ipykernel_31292\3593587878.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['위도']=lon
# C:\Users\shjo\AppData\Local\Temp\ipykernel_31292\3593587878.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1
# Out:
#          주차장명  주차면수   시간당주차요금           경도         위도    동명
# 0    동서울호텔길 A    45        250  127.091861  37.534150  구의3동
# 1    동서울호텔길 A    47        250  127.091861  37.534150  구의3동
# 2     송림식당길 A    85        200  127.076033  37.534432  자양3동
# 3     송림식당길 B    17        200  127.075217  37.532882  자양3동
# 4        광진광장    36        250  127.073625  37.547741   군자동
# 5        자양4동    86        150  127.068162  37.538662  자양4동
# 6        구의1동   172        150  127.087849  37.538262  구의1동
# 7        구의3동   160        150  127.091335  37.539097  구의3동
# 8          능동    77         75  127.080217  37.554026    능동
# 9   중곡3동 마을공원   163         75  127.084637  37.569943  중곡3동
# 10    자양동 유수지   289        150  127.077510  37.529367  자양2동
# 11        화양동    44        150  127.072242  37.545561   화양동
# 12    중곡복개천 A    35        200  127.083247  37.561529  중곡2동
# 13    중곡복개천 B    44        200   27.083247  37.561529  중곡2동
# 14      신성시장길    38        250  127.088348  37.558038  중곡4동

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   주차장명       15 non-null     object
#  1   주차면수       15 non-null     int64
#  2    시간당주차요금   15 non-null     int64
#  3   경도         15 non-null     float64
#  4   위도         15 non-null     float64
#  5   동명         15 non-null     object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 848.0+ bytes

# %%
df1.to_csv("시설관리공단 공영주차장.csv",index=False)

# %%
a=pd.read_csv("시설관리공단 공영주차장.csv")
a
# Out:
#          주차장명  주차면수   시간당주차요금           경도         위도    동명
# 0    동서울호텔길 A    45        250  127.091861  37.534150  구의3동
# 1    동서울호텔길 A    47        250  127.091861  37.534150  구의3동
# 2     송림식당길 A    85        200  127.076033  37.534432  자양3동
# 3     송림식당길 B    17        200  127.075217  37.532882  자양3동
# 4        광진광장    36        250  127.073625  37.547741   군자동
# 5        자양4동    86        150  127.068162  37.538662  자양4동
# 6        구의1동   172        150  127.087849  37.538262  구의1동
# 7        구의3동   160        150  127.091335  37.539097  구의3동
# 8          능동    77         75  127.080217  37.554026    능동
# 9   중곡3동 마을공원   163         75  127.084637  37.569943  중곡3동
# 10    자양동 유수지   289        150  127.077510  37.529367  자양2동
# 11        화양동    44        150  127.072242  37.545561   화양동
# 12    중곡복개천 A    35        200  127.083247  37.561529  중곡2동
# 13    중곡복개천 B    44        200   27.083247  37.561529  중곡2동
# 14      신성시장길    38        250  127.088348  37.558038  중곡4동

# %%
df2=pd.read_csv(f"{path}/서울특별시 광진구_공영주차장 정보_20220118.csv",encoding='cp949')

# %%
df2.head()
# Out:
#    연번    운영개시일    동명          시설명            위치      부지면적  주차면수 소계  주차면수 노상  \
# 0   1  2010-09  중곡1동  중곡제일전통시장 공영    중곡1동 221-6       695       21      0.0
# 1   2  1998-03  중곡2동          장신구   중곡2동 133-10       531       22      0.0
# 2   3  1999-06  중곡2동       중곡동복개천  중곡2동 150-196       NaN       78     78.0
# 3   4  2009-04  중곡3동     중곡3동마을공원    중곡3동 195-1    3038.3      162      NaN
# 4   5  2010-01  중곡3동       중곡체육센터    중곡3동 168-8  3,690.00        6      NaN
#
#    주차면수 노외  거주자   공영  급지 주차요금 5분당 주차요금 주간 주차요금 야간 주차요금 종일  시설규모             비고
# 0     21.0  NaN    O   2     250원     NaN     3만원     NaN   NaN  구유지(지역경제과·위탁)
# 1     22.0    O  NaN   5      NaN     4만원     3만원     5만원   NaN            시유지
# 2      0.0  NaN    O   2     200원     NaN     NaN    10만원   NaN  시유도로(노상·공단위탁)
# 3    162.0    O    O   5     75원      4만원     3만원     5만원  지하2층            구유지
# 4      6.0    O  NaN   5      NaN     4만원     3만원     5만원   NaN            구유지

# %%
df2=df2[['동명','시설명','주차면수 소계','주차요금 5분당']]

# %%
lat_dic2={'경도':[127.081744,127.084000,127.086222,127.084660,127.084782,127.089886,127.090864,127.092061,127.094478,127.091651,
               127.089378,127.089358,127.088880,127.080217,127.079673,127.087849,127.089010,127.092823,127.090237,
               127.097339,127.091634,127.091347,127.098904,127.105526,127.101528,127.110315,127.081576,127.078268,
               127.076033,127.068162,127.066308,127.071247,127.071155,127.075229,127.076913,127.735722]}
lon_dic2={'위도':[37.5638634,37.5564016,37.5601391,37.5699070,37.5677625,37.5572893,37.5613791,37.5591167,37.5638630,37.5570357,37.5683178,
               37.5702820,37.5683452,37.5540256,37.5530619,37.5382528,37.5442346,37.5529173,37.5479277,37.5533101,37.5331504,37.5391332,
               37.5387758,37.5486270,37.5464231,37.5503166,37.5337793,37.5295198,37.5344317,37.5386621,37.5400056,37.5465980,37.5452826,
               37.5450549,37.5540548,34.7421598]}
lat=pd.DataFrame(lat_dic2)
lon=pd.DataFrame(lon_dic2)
df2['경도']=lat
df2['위도']=lon

# %%
df2['주차요금 5분당']=df2['주차요금 5분당'].fillna(0)

# %%
df2
# Out:
#       동명               시설명  주차면수 소계 주차요금 5분당          경도         위도
# 0   중곡1동       중곡제일전통시장 공영       21     250원  127.081744  37.563863
# 1   중곡2동               장신구       22        0  127.084000  37.556402
# 2   중곡2동            중곡동복개천       78     200원  127.086222  37.560139
# 3   중곡3동          중곡3동마을공원      162     75원   127.084660  37.569907
# 4   중곡3동            중곡체육센터        6        0  127.084782  37.567763
# 5   중곡4동             신성시장길       33     250원  127.089886  37.557289
# 6   중곡4동               새오름        7        0  127.090864  37.561379
# 7   중곡4동              용마산남       25        0  127.092061  37.559117
# 8   중곡4동            긴고랑길공영       53        0  127.094478  37.563863
# 9   중곡4동               해오름       20        0  127.091651  37.557036
# 10  중곡4동  뻥튀기골주차장(용마공원주차장)       18        0  127.089378  37.568318
# 11  중곡4동     중곡4동 599-6 인근        9        0  127.089358  37.570282
# 12  중곡4동             한림대부지        8        0  127.088880  37.568345
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   동명        36 non-null     object
#  1   시설명       36 non-null     object
#  2   주차면수 소계   36 non-null     int64
#  3   주차요금 5분당  36 non-null     object
#  4   경도        36 non-null     float64
#  5   위도        36 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.8+ KB

# %%
df2.to_csv("공영주차장.csv",index=False)

# %%
a=pd.read_csv("공영주차장.csv")
a
# Out:
#       동명               시설명  주차면수 소계 주차요금 5분당          경도         위도
# 0   중곡1동       중곡제일전통시장 공영       21     250원  127.081744  37.563863
# 1   중곡2동               장신구       22        0  127.084000  37.556402
# 2   중곡2동            중곡동복개천       78     200원  127.086222  37.560139
# 3   중곡3동          중곡3동마을공원      162     75원   127.084660  37.569907
# 4   중곡3동            중곡체육센터        6        0  127.084782  37.567763
# 5   중곡4동             신성시장길       33     250원  127.089886  37.557289
# 6   중곡4동               새오름        7        0  127.090864  37.561379
# 7   중곡4동              용마산남       25        0  127.092061  37.559117
# 8   중곡4동            긴고랑길공영       53        0  127.094478  37.563863
# 9   중곡4동               해오름       20        0  127.091651  37.557036
# 10  중곡4동  뻥튀기골주차장(용마공원주차장)       18        0  127.089378  37.568318
# 11  중곡4동     중곡4동 599-6 인근        9        0  127.089358  37.570282
# 12  중곡4동             한림대부지        8        0  127.088880  37.568345
# ...

# %% [markdown]
# # 1.2 불법주정차

# %%
df3=pd.read_csv(f"{path}/서울특별시 광진구_불법주정차 위반 단속 CCTV 위치정보_20220502.csv",encoding='cp949')

# %%
df3.head()
# Out:
#         고정형CCTV지번주소         위도          경도  자치구        단속지점명     현장구분
# 0  서울 광진구 광장동 334-2  37.547790  127.106990  광진구        모두투어앞  불법주정차구역
# 1  서울 광진구 광장동 445-3  37.543799  127.102410  광진구       광현교회 앞  불법주정차구역
# 2    서울 광진구 구의동 135  37.549593  127.081780  광진구  아차산역 5번출구 앞  불법주정차구역
# 3    서울 광진구 군자동 503  37.548609  127.071072  광진구       두산위브 앞  불법주정차구역
# 4  서울 광진구 구의동 66-62  37.545348  127.088420  광진구       국민은행 앞  불법주정차구역

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   고정형CCTV지번주소  53 non-null     object
#  1   위도           53 non-null     float64
#  2   경도           53 non-null     float64
#  3   자치구          53 non-null     object
#  4   단속지점명        53 non-null     object
#  5   현장구분         53 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 2.6+ KB

# %% [markdown]
# # 1.3 교통단속

# %%
df4=pd.read_csv(f"{path}/서울특별시_광진구_무인교통단속카메라_20220816.csv",encoding='cp949')

# %%
df4.head()
# Out:
#    무인교통단속카메라관리번호    시도명 시군구명  도로종류  도로노선번호    도로노선명  도로노선방향  \
# 0              9  서울특별시  광진구    구도     NaN   강변역로4길       3
# 1             13  서울특별시  광진구    구도     NaN   강변역로4길       3
# 2              8  서울특별시  광진구    구도     NaN     강변역로       3
# 3             12  서울특별시  광진구  특별시도     NaN     강변역로       3
# 4             14  서울특별시  광진구    구도     NaN  광나루로56길       3
#
#                소재지도로명주소               소재지지번주소         위도  ...  \
# 0   서울특별시 광진구 강변역로4길 10  서울특별시 광진구 구의동 546-11  37.535349  ...
# 1   서울특별시 광진구 강변역로4길 56   서울특별시 광진구 구의동 547-7  37.533377  ...
# 2     서울특별시 광진구 강변역로 50   서울특별시 광진구 구의동 546-1  37.534539  ...
# 3     서울특별시 광진구 강변역로 53   서울특별시 광진구 구의동 546-6  37.535169  ...
# 4  서울특별시 광진구 광나루로56길 29   서울특별시 광진구 구의동 548-1  37.536958  ...
#
#               설치장소 단속구분  제한속도  단속구간위치구분  과속단속구간길이  보호구역구분  설치연도       관리기관명  \
# 0      지너스타워 주차장 앞    4     0       NaN       NaN     NaN  2007  서울특별시 광진구청
# ...

# %%
df4.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   무인교통단속카메라관리번호  45 non-null     int64
#  1   시도명            45 non-null     object
#  2   시군구명           45 non-null     object
#  3   도로종류           45 non-null     object
#  4   도로노선번호         34 non-null     float64
#  5   도로노선명          45 non-null     object
#  6   도로노선방향         45 non-null     int64
#  7   소재지도로명주소       45 non-null     object
#  8   소재지지번주소        45 non-null     object
#  9   위도             45 non-null     float64
#  10  경도             45 non-null     float64
#  11  설치장소           45 non-null     object
#  12  단속구분           45 non-null     int64
#  13  제한속도           45 non-null     int64
#  14  단속구간위치구분       0 non-null      float64
#  15  과속단속구간길이       0 non-null      float64
#  16  보호구역구분         5 non-null      float64
# ...

# %%
dong_dic2={'동명':['구의3동','구의3동','구의3동','구의3동','구의3동','구의3동','구의3동','능동','능동','군자동','군자동','중곡2동','중곡1동','자양4동','중곡4동','중곡1동','광장동','광장동','구의2동','중곡4동','군자동','능동','능동','자양2동','군자동','중곡1동','구의3동','화양동','화양동','화양동','화양동','자양4동','구의2동','군자동','중곡1동','자양2동','자양2동','중곡3동','광장동','구의1동','구의1동','구의2동','자양3동','군자동','자양1동']}
dong2=pd.DataFrame(dong_dic2)
df4['동명']=dong2

# %%
df4=df4[['설치장소','동명','위도','경도']]

# %%
df4
# Out:
#                설치장소    동명         위도          경도
# 0       지너스타워 주차장 앞  구의3동  37.535349  127.093405
# 1      동서울터미널 주차장 앞  구의3동  37.533377  127.092166
# 2       리젠트오피스텔 건너편  구의3동  37.534539  127.094184
# 3          강변역 4번출구  구의3동  37.535169  127.094665
# 4   프라임아파트 정문(213동)  구의3동  37.536958  127.096537
# 5          강변역 1번출구  구의3동  37.535169  127.094665
# 6        현대2단지아파트 앞  구의3동  37.537871  127.096219
# 7         어린이대공원 정문    능동  37.547246  127.078304
# 8       서울시민안전체험관 앞    능동  37.552162  127.077254
# 9           군자CGV 앞   군자동  37.556179  127.078499
# 10      세종대정문 택시승강장   군자동  37.551325  127.076102
# 11       고신경정신과의원 앞  중곡2동  37.558389  127.080390
# 12          태양주유소 앞  중곡1동  37.561604  127.074684
# 13            올포유 앞  자양4동  37.536666  127.062876
# 14           우리은행 앞  중곡4동  37.557469  127.088244
# 15          MB모터스 옆  중곡1동  37.563496  127.078263
# 16           모두투어 앞   광장동  37.547576  127.106993
# 17           광현교회 앞   광장동  37.543670  127.102485
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   설치장소    45 non-null     object
#  1   동명      45 non-null     object
#  2   위도      45 non-null     float64
#  3   경도      45 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.5+ KB

# %%
df4.to_csv("무인교통단속카메라.csv",index=False)

# %%
a=pd.read_csv("무인교통단속카메라.csv")
a
# Out:
#                설치장소    동명         위도          경도
# 0       지너스타워 주차장 앞  구의3동  37.535349  127.093405
# 1      동서울터미널 주차장 앞  구의3동  37.533377  127.092166
# 2       리젠트오피스텔 건너편  구의3동  37.534539  127.094184
# 3          강변역 4번출구  구의3동  37.535169  127.094665
# 4   프라임아파트 정문(213동)  구의3동  37.536958  127.096537
# 5          강변역 1번출구  구의3동  37.535169  127.094665
# 6        현대2단지아파트 앞  구의3동  37.537871  127.096219
# 7         어린이대공원 정문    능동  37.547246  127.078304
# 8       서울시민안전체험관 앞    능동  37.552162  127.077254
# 9           군자CGV 앞   군자동  37.556179  127.078499
# 10      세종대정문 택시승강장   군자동  37.551325  127.076102
# 11       고신경정신과의원 앞  중곡2동  37.558389  127.080390
# 12          태양주유소 앞  중곡1동  37.561604  127.074684
# 13            올포유 앞  자양4동  37.536666  127.062876
# 14           우리은행 앞  중곡4동  37.557469  127.088244
# 15          MB모터스 옆  중곡1동  37.563496  127.078263
# 16           모두투어 앞   광장동  37.547576  127.106993
# 17           광현교회 앞   광장동  37.543670  127.102485
# ...

# %% [markdown]
# # 2. 신호등 + 가로등

# %% [markdown]
# # 2.1 신호등

# %%
df5=pd.read_csv(f"{path}/서울특별시 광진구_LED바닥형신호등_20230204.csv",encoding='cp949')

# %%
df5=df5[['상세위치','수량','경도','위도']]

# %%
dong_dic3={'동명':['중곡3동','구의3동','구의3동','자양4동','화양동','자양3동','중곡4동','광장동','구의2동','구의1동','자양3동','자양1동','자양1동','군자동','자양3동','구의3동','자양1동','군자동','중곡3동','화양동','구의2동','자양1동','자양1동','중곡4동','중곡4동','중곡4동','중곡4동','구의3동','구의1동','구의2동','구의2동','구의3동','자양3동','중곡3동','자양2동','광장동','중곡2동','중곡3동','구의3동','중곡1동','광장동','군자동','자양1동','광장동','중곡4동','중곡4동','중곡2동','자양3동','중곡1동','자양2동','구의1동','자양1동','자양3동','군자동','구의3동','구의3동','군자동']}
dong3=pd.DataFrame(dong_dic3)
df5['동명']=dong3

# %%
df5
# Out:
#             상세위치  수량          경도         위도    동명
# 0         중마초등학교   1  127.080740  37.565205  중곡3동
# 1    강변역(동서울터미널)   2  127.093405  37.535352  구의3동
# 2    강변역(동서울터미널)   1  127.094185  37.534538  구의3동
# 3          건대입구역   2  127.070201  37.539731  자양4동
# 4          건대입구역   1  127.070510  37.540337   화양동
# 5          건대입구역   1  127.071217  37.539000  자양3동
# 6           아차산역   2  127.089722  37.552597  중곡4동
# 7         광장초등학교   1  127.102329  37.546998   광장동
# 8         광진초등학교   1  127.088842  37.548652  구의2동
# 9         구의초등학교   1  127.083821  37.540945  구의1동
# 10        동자초등학교   1  127.071275  37.534306  자양3동
# 11        성자초등학교   1  127.082318  37.531590  자양1동
# 12        성자초등학교   1  127.082634  37.531619  자양1동
# 13        세종초등학교   1  127.072877  37.553024   군자동
# 14        신양초등학교   1  127.070078  37.535026  자양3동
# 15        양진초등학교   1  127.093848  37.542690  구의3동
# 16        자양초등학교   1  127.079005  37.537844  자양1동
# 17        장안초등학교   1  127.071058  37.549974   군자동
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상세위치    57 non-null     object
#  1   수량      57 non-null     int64
#  2   경도      57 non-null     float64
#  3   위도      57 non-null     float64
#  4   동명      57 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.4+ KB

# %%
df5.to_csv("LED바닥형 신호등.csv",index=False)

# %%
a=pd.read_csv("LED바닥형 신호등.csv")
a
# Out:
#             상세위치  수량          경도         위도    동명
# 0         중마초등학교   1  127.080740  37.565205  중곡3동
# 1    강변역(동서울터미널)   2  127.093405  37.535352  구의3동
# 2    강변역(동서울터미널)   1  127.094185  37.534538  구의3동
# 3          건대입구역   2  127.070201  37.539731  자양4동
# 4          건대입구역   1  127.070510  37.540337   화양동
# 5          건대입구역   1  127.071217  37.539000  자양3동
# 6           아차산역   2  127.089722  37.552597  중곡4동
# 7         광장초등학교   1  127.102329  37.546998   광장동
# 8         광진초등학교   1  127.088842  37.548652  구의2동
# 9         구의초등학교   1  127.083821  37.540945  구의1동
# 10        동자초등학교   1  127.071275  37.534306  자양3동
# 11        성자초등학교   1  127.082318  37.531590  자양1동
# 12        성자초등학교   1  127.082634  37.531619  자양1동
# 13        세종초등학교   1  127.072877  37.553024   군자동
# 14        신양초등학교   1  127.070078  37.535026  자양3동
# 15        양진초등학교   1  127.093848  37.542690  구의3동
# 16        자양초등학교   1  127.079005  37.537844  자양1동
# 17        장안초등학교   1  127.071058  37.549974   군자동
# ...

# %% [markdown]
# # 3. 어린이보호구역

# %%
df6=pd.read_csv(f"{path}/어린이보호구역 위치도.csv",encoding='cp949')

# %%
df6.head()
# Out:
#     아이디                                       geometry  관리번호  관할경찰서    구   동  \
# 0  2277  MULTIPOINT(962452.511040574 1949891.98142482)     0  광진경찰서  광진구 NaN
# 1  2278  MULTIPOINT(963491.283023257 1949536.09357659)     0  광진경찰서  광진구 NaN
# 2  2279   MULTIPOINT(961193.00565172 1950061.30704031)     0  광진경찰서  광진구 NaN
# 3  2280  MULTIPOINT(962120.220997693 1949375.92449068)     0  광진경찰서  광진구 NaN
# 4  2281   MULTIPOINT(962663.633282424 1949361.0380544)     0  광진경찰서  광진구 NaN
#
#         시설명  시설구분                          주소         x좌표        y좌표
# 0  어린이회관유치원   유치원          서울특별시 광진구 광나루길 441  127.074938  37.547599
# 1     현정유치원   유치원  서울특별시 광진구 광나루로 534-1 (구의동)  127.088898  37.544478
# 2    수정어린이집  어린이집  서울특별시 광진구 광나루로15길 17 (군자동)  127.069405  37.549059
# 3    구의초등학교  초등학교        서울특별시 광진구 광나루로30길 49  127.080862  37.542736
# 4   구의병설유치원   유치원        서울특별시 광진구 광나루로30길 49  127.080862  37.542736

# %%
df6=df6[['시설명','시설구분','x좌표','y좌표']]

# %%
dong_dic4={'동명':['능동','구의1동','군자동','화양동','화양동','구의1동','구의3동','구의3동','군자동','군자동','화양동','군자동',
'중곡4동','중곡3동','중곡3동','중곡3동','자양3동','자양3동','자양3동','중곡3동','군자동','중곡3동','중곡3동','중곡3동','자양4동','중곡3동','중곡3동',
'자양3동','자양4동','자양3동','자양1동','자양4동','자양3동','자양1동','자양2동','군자동','군자동','화양동','자양1동','자양1동','자양1동','자양1동','구의1동','중곡3동',
'중곡4동','중곡2동','자양2동','자양2동','구의2동','자양2동','자양3동','중곡2동','중곡2동','군자동','능동','구의2동','구의2동','구의3동','광장동','광장동','광장동','광장동','구의3동',
'구의3동','자양2동','자양2동','자양2동','광장동','광장동','광장동','구의3동','광장동','광장동','구의2동','구의2동','구의2동','구의2동','구의2동','구의2동','자양2동',
]}
dong4=pd.DataFrame(dong_dic4)
df6['동명']=dong4

# %%
df6
# Out:
#          시설명  시설구분         x좌표        y좌표    동명
# 0   어린이회관유치원   유치원  127.074938  37.547599    능동
# 1      현정유치원   유치원  127.088898  37.544478  구의1동
# 2     수정어린이집  어린이집  127.069405  37.549059   군자동
# 3     구의초등학교  초등학교  127.080862  37.542736   화양동
# 4    구의병설유치원   유치원  127.080862  37.542736   화양동
# ..       ...   ...         ...        ...   ...
# 75     경원유치원   유치원  127.096107  37.554870  구의2동
# 76     슬기유치원   유치원  127.092584  37.552053  구의2동
# 77    광진초등학교  초등학교  127.091210  37.547585  구의2동
# 78  구의2동어린이집  어린이집  127.096237  37.550176  구의2동
# 79    성동초등학교  초등학교  127.089506  37.532918  자양2동
#
# [80 rows x 5 columns]

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시설명     80 non-null     object
#  1   시설구분    80 non-null     object
#  2   x좌표     80 non-null     float64
#  3   y좌표     80 non-null     float64
#  4   동명      80 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 3.2+ KB

# %%
df6.to_csv("어린이보호구역.csv",index=False)

# %%
a=pd.read_csv("어린이보호구역.csv")
a
# Out:
#          시설명  시설구분         x좌표        y좌표    동명
# 0   어린이회관유치원   유치원  127.074938  37.547599    능동
# 1      현정유치원   유치원  127.088898  37.544478  구의1동
# 2     수정어린이집  어린이집  127.069405  37.549059   군자동
# 3     구의초등학교  초등학교  127.080862  37.542736   화양동
# 4    구의병설유치원   유치원  127.080862  37.542736   화양동
# ..       ...   ...         ...        ...   ...
# 75     경원유치원   유치원  127.096107  37.554870  구의2동
# 76     슬기유치원   유치원  127.092584  37.552053  구의2동
# 77    광진초등학교  초등학교  127.091210  37.547585  구의2동
# 78  구의2동어린이집  어린이집  127.096237  37.550176  구의2동
# 79    성동초등학교  초등학교  127.089506  37.532918  자양2동
#
# [80 rows x 5 columns]

# %% [markdown]
# # 4. 전기차 + 전체 자동차 등록대수

# %%
df7=pd.read_csv(f"{path}/서울특별시 광진구_자동차등록대수_20230330.csv",encoding='cp949')
df8=pd.read_csv(f"{path}/서울특별시 광진구_전기차 등록대수_20211231.csv",encoding='cp949')

# %%
df7
# Out:
#     읍면동명  자동차등록대수
# 0    광장동    11646
# 1   구의1동     7005
# 2   구의2동     7346
# 3   구의3동     9127
# 4    군자동     5223
# 5     능동     3060
# 6   자양1동     7366
# 7   자양2동     7598
# 8   자양3동     8970
# 9   자양4동     5018
# 10  중곡1동     4753
# 11  중곡2동     5132
# 12  중곡3동     4073
# 13  중곡4동     7382
# 14   화양동     4186

# %%
df8
# Out:
#     연번    시도명 자치구명       연월  전기차 등록대수
# 0    1  서울특별시  광진구  2018-01        48
# 1    2  서울특별시  광진구  2018-02        46
# 2    3  서울특별시  광진구  2018-03        65
# 3    4  서울특별시  광진구  2018-04        68
# 4    5  서울특별시  광진구  2018-05        74
# 5    6  서울특별시  광진구  2018-06        84
# 6    7  서울특별시  광진구  2018-07        91
# 7    8  서울특별시  광진구  2018-08        96
# 8    9  서울특별시  광진구  2018-09       103
# 9   10  서울특별시  광진구  2018-10       113
# 10  11  서울특별시  광진구  2018-11       117
# 11  12  서울특별시  광진구  2018-12       123
# 12  13  서울특별시  광진구  2019-01       123
# 13  14  서울특별시  광진구  2019-02       126
# 14  15  서울특별시  광진구  2019-03       137
# 15  16  서울특별시  광진구  2019-04       138
# 16  17  서울특별시  광진구  2019-05       145
# 17  18  서울특별시  광진구  2019-06       157
# 18  19  서울특별시  광진구  2019-07       167
# 19  20  서울특별시  광진구  2019-08       166
# 20  21  서울특별시  광진구  2019-09       168
# 21  22  서울특별시  광진구  2019-10       165
# 22  23  서울특별시  광진구  2019-11       182
# 23  24  서울특별시  광진구  2019-12       191
# ...

# %% [markdown]
# # 5. 어린이집

# %%
df9=pd.read_csv(f"{path}/서울특별시 광진구_어린이집_20230207.csv",encoding='cp949')

# %%
df9
# Out:
#           어린이집명    시도명 시군구명 어린이집유형구분  정원수  보육교직원수  \
# 0        EQ어린이집  서울특별시  광진구       가정   20       5
# 1     KB구의 어린이집  서울특별시  광진구       직장   49      15
# 2     강변에코비어린이집  서울특별시  광진구       가정   19       5
# 3     건대꼬마숲어린이집  서울특별시  광진구       민간   48       9
# 4      고은아이어린이집  서울특별시  광진구       가정   19       8
# ..          ...    ...  ...      ...  ...     ...
# 139     해오름어린이집  서울특별시  광진구       민간   24       4
# 140     해피i어린이집  서울특별시  광진구       가정   19       7
# 141    향기나무어린이집  서울특별시  광진구       가정   20       8
# 142  현대몬테소리어린이집  서울특별시  광진구       가정   20       8
# 143  현대아이사랑어린이집  서울특별시  광진구       가정   19       6
#
#                                             소재지도로명주소      어린이집전화번호  \
# 0                          서울특별시 광진구 동일로26길 41 (화양동)   02-466-1071
# 1                              서울특별시 광진구 광나루로 525 3층  02-6235-7977
# 2                       서울특별시 광진구 구의강변로 42 101동 108호  02-3436-0260
# 3                          서울특별시 광진구 동일로28길 45 (화양동)   02-467-6489
# ...

# %%
df9=df9[['어린이집명','어린이집유형구분','정원수','보육교직원수','보육실수','놀이터수']]

# %%
dong_dic5={'동명':['화양동','구의2동','구의3동','화양동','자양4동','자양1동','자양1동','자양3동','광장동','구의1동','구의1동','구의2동','구의3동','군자동','군자동','광장동','화양동','능동',
'능동','능동','중곡4동','구의3동','구의1동','자양3동','광장동','구의3동','광장동','자양4동','구의3동','광장동','중곡3동','자양2동','광장동','중곡2동','중곡2동','구의3동','중곡2동','광장동',
'구의3동','광장동','자양4동','군자동','자양1동','자양2동','자양4동','자양1동','자양3동','자양4동','중곡1동','중곡1동','중곡3동','중곡3동','중곡2동','자양1동','중곡4동','구의2동',
'군자동','자양2동','자양2동','화양동','자양3동','구의2동','중곡4동','구의2동','군자동','광장동','구의3동','중곡4동','중곡1동','중곡3동','구의1동','군자동','광장동','중곡3동','광장동',
'능동','자양3동','자양4동','자양1동','구의3동','구의1동','자양2동','자양3동','중곡4동','자양3동','자양1동','중곡2동','자양2동','구의3동','중곡4동','군자동','자양4동','중곡3동',
'구의1동','구의2동','자양3동','중곡2동','자양3동','구의2동','중곡2동','자양3동','자양2동','중곡2동','광장동','구의2동','자양4동','구의1동','중곡3동','광장동','구의2동','구의2동',
'중곡3동','구의2동','군자동','중곡2동','광장동','자양3동','자양3동','자양3동','화양동','자양1동','구의3동','중곡4동','중곡4동','구의2동','자양2동','자양2동','중곡2동','중곡4동',
'자양1동','광장동','자양2동','중곡4동','구의3동','중곡3동','자양3동','중곡2동','구의3동','자양4동','구의2동','자양3동','광장동','구의3동','구의3동',]}
dong5=pd.DataFrame(dong_dic5)
df9['동명']=dong5
# Out:
# C:\Users\shjo\AppData\Local\Temp\ipykernel_31292\1991787569.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df9['동명']=dong5

# %%
df9
# Out:
#           어린이집명 어린이집유형구분  정원수  보육교직원수  보육실수  놀이터수    동명
# 0        EQ어린이집       가정   20       5     3     4   화양동
# 1     KB구의 어린이집       직장   49      15     4     1  구의2동
# 2     강변에코비어린이집       가정   19       5     4     0  구의3동
# 3     건대꼬마숲어린이집       민간   48       9     6     1   화양동
# 4      고은아이어린이집       가정   19       8     4     0  자양4동
# ..          ...      ...  ...     ...   ...   ...   ...
# 139     해오름어린이집       민간   24       4     4     0  구의2동
# 140     해피i어린이집       가정   19       7     4     1  자양3동
# 141    향기나무어린이집       가정   20       8     4     2   광장동
# 142  현대몬테소리어린이집       가정   20       8     5     0  구의3동
# 143  현대아이사랑어린이집       가정   19       6     4     0  구의3동
#
# [144 rows x 7 columns]

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   어린이집명     144 non-null    object
#  1   어린이집유형구분  144 non-null    object
#  2   정원수       144 non-null    int64
#  3   보육교직원수    144 non-null    int64
#  4   보육실수      144 non-null    int64
#  5   놀이터수      144 non-null    int64
#  6   동명        144 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 8.0+ KB

# %% [markdown]
# # 6. 인구현황

# %%
df10=pd.read_csv(f"{path}/서울특별시_광진구_인구현황_20221231.csv",encoding='cp949')

# %%
df10
# Out:
#      행정기관       계  인구수(남)  인구수(여)  지역(구성비)  구성비(남)  구성비(여)     성비     세대수  \
# 0     광진구  337416  162541  174875   100.00   48.17   51.83  92.95  169291
# 1   중곡제1동   15299    7322    7977     4.53    2.17    2.36  91.79    8504
# 2   중곡제2동   20999    9903   11096     6.22    2.93    3.29  89.25   10656
# 3   중곡제3동   15945    7897    8048     4.73    2.34    2.39  98.12    8513
# 4   중곡제4동   28035   13715   14320     8.31    4.06    4.24  95.78   13122
# 5      능동   11180    5134    6046     3.31    1.52    1.79  84.92    6406
# 6   구의제1동   23387   11143   12244     6.93    3.30    3.63  91.01   13077
# 7   구의제2동   26043   12511   13532     7.72    3.71    4.01  92.45   11517
# 8   구의제3동   28211   13309   14902     8.36    3.94    4.42  89.31   12079
# 9     광장동   34168   16524   17644    10.13    4.90    5.23  93.65   11814
# 10  자양제1동   21862   10646   11216     6.48    3.16    3.32  94.92   11913
# 11  자양제2동   23946   11612   12334     7.10    3.44    3.66  94.15   10887
# ...

# %%
df10['행정기관'].replace({'중곡제1동':'중곡1동','중곡제2동':'중곡2동','중곡제3동':'중곡3동','중곡제4동':'중곡4동',
                '구의제1동':'구의1동','구의제2동':'구의2동','구의제3동':'구의3동',
                '자양제1동':'자양1동','자양제2동':'자양2동','자양제3동':'자양3동','자양제4동':'자양4동'},inplace=True)

# %%
df10
# Out:
#     행정기관       계  인구수(남)  인구수(여)  지역(구성비)  구성비(남)  구성비(여)     성비     세대수  \
# 0    광진구  337416  162541  174875   100.00   48.17   51.83  92.95  169291
# 1   중곡1동   15299    7322    7977     4.53    2.17    2.36  91.79    8504
# 2   중곡2동   20999    9903   11096     6.22    2.93    3.29  89.25   10656
# 3   중곡3동   15945    7897    8048     4.73    2.34    2.39  98.12    8513
# 4   중곡4동   28035   13715   14320     8.31    4.06    4.24  95.78   13122
# 5     능동   11180    5134    6046     3.31    1.52    1.79  84.92    6406
# 6   구의1동   23387   11143   12244     6.93    3.30    3.63  91.01   13077
# 7   구의2동   26043   12511   13532     7.72    3.71    4.01  92.45   11517
# 8   구의3동   28211   13309   14902     8.36    3.94    4.42  89.31   12079
# 9    광장동   34168   16524   17644    10.13    4.90    5.23  93.65   11814
# 10  자양1동   21862   10646   11216     6.48    3.16    3.32  94.92   11913
# 11  자양2동   23946   11612   12334     7.10    3.44    3.66  94.15   10887
# ...
